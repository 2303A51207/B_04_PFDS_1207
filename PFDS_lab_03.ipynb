# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51207/B_04_PFDS_1207/blob/main/PFDS_lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 problem
import numpy as np

a = np.random.randint(1, 10, (3, 3))
b = np.random.randint(1, 10, (3, 3))

add = np.add(a, b)
sub = np.subtract(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Addition:\n", add)
print("Subtraction:\n", sub)
# Out:
# Matrix A:
#  [[1 6 5]
#  [9 5 6]
#  [5 3 1]]
# Matrix B:
#  [[2 5 9]
#  [3 5 3]
#  [6 9 2]]
# Addition:
#  [[ 3 11 14]
#  [12 10  9]
#  [11 12  3]]
# Subtraction:
#  [[-1  1 -4]
#  [ 6  0  3]
#  [-1 -6 -1]]

# %%
# 2 problem
import numpy as np
import matplotlib.pyplot as plt

a = np.random.randint(1, 5, (3, 2))
b = np.random.randint(1, 5, (2, 3))
c = np.dot(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Dot Product:\n", c)


plt.figure(figsize=(8, 3))

plt.subplot(1, 3, 1)
plt.imshow(a, cmap='viridis', interpolation='nearest')
plt.title("Matrix A")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(b, cmap='viridis', interpolation='nearest')
plt.title("Matrix B")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(c, cmap='viridis', interpolation='nearest')
plt.title("Dot Product")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Matrix A:
#  [[4 4]
#  [4 2]
#  [1 4]]
# Matrix B:
#  [[3 3 4]
#  [1 3 2]]
# Dot Product:
#  [[16 24 24]
#  [14 18 20]
#  [ 7 15 12]]

# %%
#ClassRoom_Files
import csv

with open("Classroom_file.csv", 'w', newline='') as fp:
    wr = csv.writer(fp)
    wr.writerow(["Name", "Marks"])
    for i in range(2):
        name = input("Enter name: ")
        marks = int(input("Enter marks: "))
        wr.writerow([name, marks])
# Out:
# Enter name: sri
# Enter marks: 76
# Enter name: ram
# Enter marks: 79
